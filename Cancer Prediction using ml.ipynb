# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df=pd.read_csv('Cancer.csv')

# %%
df.head()
# Out:
#   Patient Id  Age  Gender  AirPollution  Alcoholuse  DustAllergy  \
# 0         P1   33       1             2           4            5
# 1        P10   17       1             3           1            5
# 2       P100   35       1             4           5            6
# 3      P1000   37       1             7           7            7
# 4       P101   46       1             6           8            7
#
#    OccuPationalHazards  GeneticRisk  chronicLungDisease  BalancedDiet  ...  \
# 0                    4            3                   2             2  ...
# 1                    3            4                   2             2  ...
# 2                    5            5                   4             6  ...
# 3                    7            6                   7             7  ...
# 4                    7            7                   6             7  ...
#
#    Fatigue  WeightLoss  ShortnessofBreath  Wheezing  SwallowingDifficulty  \
# 0        3           4                  2         2                     3
# 1        1           3                  7         8                     6
# 2        8           7                  9         2                     1
# 3        4           2                  3         1                     4
# 4        3           2                  4         1                     4
#
#    ClubbingofFingerNails  FrequentCold  DryCough  Snoring  Level
# 0                      1             2         3        4    Low
# 1                      2             1         7        2   High
# 2                      4             6         7        2   High
# 3                      5             6         7        5   High
# 4                      2             4         2        3   High
#
# [5 rows x 25 columns]

# %%
df['Level']
# Out:
# 0        Low
# 1       High
# 2       High
# 3       High
# 4       High
#         ...
# 2963    High
# 2964    High
# 2965    High
# 2966    High
# 2967    High
# Name: Level, Length: 2968, dtype: object

# %%
df['Level'].replace('Medium','High',inplace=True)

# %%
df['Level']
# Out:
# 0        Low
# 1       High
# 2       High
# 3       High
# 4       High
#         ...
# 2963    High
# 2964    High
# 2965    High
# 2966    High
# 2967    High
# Name: Level, Length: 2968, dtype: object

# %%
df.tail()
# Out:
#      Patient Id  Age  Gender  AirPollution  Alcoholuse  DustAllergy  \
# 2963        P99   37       1             7           7            7
# 2964       P990   49       1             6           5            6
# 2965       P991   37       1             8           8            7
# 2966       P992   26       2             7           7            7
# 2967       P993   37       2             7           7            7
#
#       OccuPationalHazards  GeneticRisk  chronicLungDisease  BalancedDiet  ...  \
# 2963                    7            6                   7             7  ...
# 2964                    5            5                   4             6  ...
# 2965                    7            7                   6             7  ...
# 2966                    7            7                   6             7  ...
# 2967                    7            6                   7             7  ...
#
#       Fatigue  WeightLoss  ShortnessofBreath  Wheezing  SwallowingDifficulty  \
# 2963        4           2                  3         1                     4
# 2964        8           7                  9         2                     1
# 2965        3           2                  4         1                     4
# 2966        2           7                  6         7                     6
# 2967        4           2                  3         1                     4
#
#       ClubbingofFingerNails  FrequentCold  DryCough  Snoring  Level
# 2963                      5             6         7        5   High
# 2964                      4             6         7        2   High
# 2965                      2             4         2        3   High
# 2966                      7             2         3        1   High
# 2967                      5             6         7        5   High
#
# [5 rows x 25 columns]

# %%
df.isnull()
# Out:
#       Patient Id    Age  Gender  AirPollution  Alcoholuse  DustAllergy  \
# 0          False  False   False         False       False        False
# 1          False  False   False         False       False        False
# 2          False  False   False         False       False        False
# 3          False  False   False         False       False        False
# 4          False  False   False         False       False        False
# ...          ...    ...     ...           ...         ...          ...
# 2963       False  False   False         False       False        False
# 2964       False  False   False         False       False        False
# 2965       False  False   False         False       False        False
# 2966       False  False   False         False       False        False
# 2967       False  False   False         False       False        False
#
#       OccuPationalHazards  GeneticRisk  chronicLungDisease  BalancedDiet  ...  \
# 0                   False        False               False         False  ...
# 1                   False        False               False         False  ...
# 2                   False        False               False         False  ...
# 3                   False        False               False         False  ...
# 4                   False        False               False         False  ...
# ...                   ...          ...                 ...           ...  ...
# 2963                False        False               False         False  ...
# 2964                False        False               False         False  ...
# 2965                False        False               False         False  ...
# 2966                False        False               False         False  ...
# 2967                False        False               False         False  ...
#
#       Fatigue  WeightLoss  ShortnessofBreath  Wheezing  SwallowingDifficulty  \
# 0       False       False              False     False                 False
# 1       False       False              False     False                 False
# 2       False       False              False     False                 False
# 3       False       False              False     False                 False
# 4       False       False              False     False                 False
# ...       ...         ...                ...       ...                   ...
# 2963    False       False              False     False                 False
# 2964    False       False              False     False                 False
# 2965    False       False              False     False                 False
# 2966    False       False              False     False                 False
# 2967    False       False              False     False                 False
#
#       ClubbingofFingerNails  FrequentCold  DryCough  Snoring  Level
# 0                     False         False     False    False  False
# 1                     False         False     False    False  False
# 2                     False         False     False    False  False
# 3                     False         False     False    False  False
# 4                     False         False     False    False  False
# ...                     ...           ...       ...      ...    ...
# 2963                  False         False     False    False  False
# 2964                  False         False     False    False  False
# 2965                  False         False     False    False  False
# 2966                  False         False     False    False  False
# 2967                  False         False     False    False  False
#
# [2968 rows x 25 columns]

# %%
df.isnull().any()
# Out:
# Patient Id               False
# Age                      False
# Gender                   False
# AirPollution             False
# Alcoholuse               False
# DustAllergy              False
# OccuPationalHazards      False
# GeneticRisk              False
# chronicLungDisease       False
# BalancedDiet             False
# Obesity                  False
# Smoking                  False
# PassiveSmoker            False
# ChestPain                False
# CoughingofBlood          False
# Fatigue                  False
# WeightLoss               False
# ShortnessofBreath        False
# Wheezing                 False
# SwallowingDifficulty     False
# ClubbingofFingerNails    False
# FrequentCold             False
# DryCough                 False
# Snoring                  False
# Level                    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Patient Id               0
# Age                      0
# Gender                   0
# AirPollution             0
# Alcoholuse               0
# DustAllergy              0
# OccuPationalHazards      0
# GeneticRisk              0
# chronicLungDisease       0
# BalancedDiet             0
# Obesity                  0
# Smoking                  0
# PassiveSmoker            0
# ChestPain                0
# CoughingofBlood          0
# Fatigue                  0
# WeightLoss               0
# ShortnessofBreath        0
# Wheezing                 0
# SwallowingDifficulty     0
# ClubbingofFingerNails    0
# FrequentCold             0
# DryCough                 0
# Snoring                  0
# Level                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1968

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['Level'].replace('Low',0,inplace=True)
df['Level'].replace('High',1,inplace=True)
# Out:
# C:\Users\VARSHITHA\AppData\Local\Temp\ipykernel_1400\2138442393.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Level'].replace('High',1,inplace=True)

# %%
df['Level']
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2963    1
# 2964    1
# 2965    1
# 2966    1
# 2967    1
# Name: Level, Length: 2968, dtype: int64

# %%
df.head()
# Out:
#   Patient Id  Age  Gender  AirPollution  Alcoholuse  DustAllergy  \
# 0         P1   33       1             2           4            5
# 1        P10   17       1             3           1            5
# 2       P100   35       1             4           5            6
# 3      P1000   37       1             7           7            7
# 4       P101   46       1             6           8            7
#
#    OccuPationalHazards  GeneticRisk  chronicLungDisease  BalancedDiet  ...  \
# 0                    4            3                   2             2  ...
# 1                    3            4                   2             2  ...
# 2                    5            5                   4             6  ...
# 3                    7            6                   7             7  ...
# 4                    7            7                   6             7  ...
#
#    Fatigue  WeightLoss  ShortnessofBreath  Wheezing  SwallowingDifficulty  \
# 0        3           4                  2         2                     3
# 1        1           3                  7         8                     6
# 2        8           7                  9         2                     1
# 3        4           2                  3         1                     4
# 4        3           2                  4         1                     4
#
#    ClubbingofFingerNails  FrequentCold  DryCough  Snoring  Level
# 0                      1             2         3        4      0
# 1                      2             1         7        2      1
# 2                      4             6         7        2      1
# 3                      5             6         7        5      1
# 4                      2             4         2        3      1
#
# [5 rows x 25 columns]

# %%
df.drop(['Patient Id'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  AirPollution  Alcoholuse  DustAllergy  OccuPationalHazards  \
# 0   33       1             2           4            5                    4
# 1   17       1             3           1            5                    3
# 2   35       1             4           5            6                    5
# 3   37       1             7           7            7                    7
# 4   46       1             6           8            7                    7
#
#    GeneticRisk  chronicLungDisease  BalancedDiet  Obesity  ...  Fatigue  \
# 0            3                   2             2        4  ...        3
# 1            4                   2             2        2  ...        1
# 2            5                   4             6        7  ...        8
# 3            6                   7             7        7  ...        4
# 4            7                   6             7        7  ...        3
#
#    WeightLoss  ShortnessofBreath  Wheezing  SwallowingDifficulty  \
# 0           4                  2         2                     3
# 1           3                  7         8                     6
# 2           7                  9         2                     1
# 3           2                  3         1                     4
# 4           2                  4         1                     4
#
#    ClubbingofFingerNails  FrequentCold  DryCough  Snoring  Level
# 0                      1             2         3        4      0
# 1                      2             1         7        2      1
# 2                      4             6         7        2      1
# 3                      5             6         7        5      1
# 4                      2             4         2        3      1
#
# [5 rows x 24 columns]

# %%
X=df.drop(['Level'],axis=1)
y=df['Level']

# %%
X
# Out:
#       Age  Gender  AirPollution  Alcoholuse  DustAllergy  OccuPationalHazards  \
# 0      33       1             2           4            5                    4
# 1      17       1             3           1            5                    3
# 2      35       1             4           5            6                    5
# 3      37       1             7           7            7                    7
# 4      46       1             6           8            7                    7
# ...   ...     ...           ...         ...          ...                  ...
# 2963   37       1             7           7            7                    7
# 2964   49       1             6           5            6                    5
# 2965   37       1             8           8            7                    7
# 2966   26       2             7           7            7                    7
# 2967   37       2             7           7            7                    7
#
#       GeneticRisk  chronicLungDisease  BalancedDiet  Obesity  ...  \
# 0               3                   2             2        4  ...
# 1               4                   2             2        2  ...
# 2               5                   4             6        7  ...
# 3               6                   7             7        7  ...
# 4               7                   6             7        7  ...
# ...           ...                 ...           ...      ...  ...
# 2963            6                   7             7        7  ...
# 2964            5                   4             6        7  ...
# 2965            7                   6             7        7  ...
# 2966            7                   6             7        7  ...
# 2967            6                   7             7        7  ...
#
#       CoughingofBlood  Fatigue  WeightLoss  ShortnessofBreath  Wheezing  \
# 0                   4        3           4                  2         2
# 1                   3        1           3                  7         8
# 2                   8        8           7                  9         2
# 3                   8        4           2                  3         1
# 4                   9        3           2                  4         1
# ...               ...      ...         ...                ...       ...
# 2963                8        4           2                  3         1
# 2964                8        8           7                  9         2
# 2965                9        3           2                  4         1
# 2966                7        2           7                  6         7
# 2967                8        4           2                  3         1
#
#       SwallowingDifficulty  ClubbingofFingerNails  FrequentCold  DryCough  \
# 0                        3                      1             2         3
# 1                        6                      2             1         7
# 2                        1                      4             6         7
# 3                        4                      5             6         7
# 4                        4                      2             4         2
# ...                    ...                    ...           ...       ...
# 2963                     4                      5             6         7
# 2964                     1                      4             6         7
# 2965                     4                      2             4         2
# 2966                     6                      7             2         3
# 2967                     4                      5             6         7
#
#       Snoring
# 0           4
# 1           2
# 2           2
# 3           5
# 4           3
# ...       ...
# 2963        5
# 2964        2
# 2965        3
# 2966        1
# 2967        5
#
# [2968 rows x 23 columns]

# %%
X
# Out:
#       Age  Gender  AirPollution  Alcoholuse  DustAllergy  OccuPationalHazards  \
# 0      33       1             2           4            5                    4
# 1      17       1             3           1            5                    3
# 2      35       1             4           5            6                    5
# 3      37       1             7           7            7                    7
# 4      46       1             6           8            7                    7
# ...   ...     ...           ...         ...          ...                  ...
# 2963   37       1             7           7            7                    7
# 2964   49       1             6           5            6                    5
# 2965   37       1             8           8            7                    7
# 2966   26       2             7           7            7                    7
# 2967   37       2             7           7            7                    7
#
#       GeneticRisk  chronicLungDisease  BalancedDiet  Obesity  ...  \
# 0               3                   2             2        4  ...
# 1               4                   2             2        2  ...
# 2               5                   4             6        7  ...
# 3               6                   7             7        7  ...
# 4               7                   6             7        7  ...
# ...           ...                 ...           ...      ...  ...
# 2963            6                   7             7        7  ...
# 2964            5                   4             6        7  ...
# 2965            7                   6             7        7  ...
# 2966            7                   6             7        7  ...
# 2967            6                   7             7        7  ...
#
#       CoughingofBlood  Fatigue  WeightLoss  ShortnessofBreath  Wheezing  \
# 0                   4        3           4                  2         2
# 1                   3        1           3                  7         8
# 2                   8        8           7                  9         2
# 3                   8        4           2                  3         1
# 4                   9        3           2                  4         1
# ...               ...      ...         ...                ...       ...
# 2963                8        4           2                  3         1
# 2964                8        8           7                  9         2
# 2965                9        3           2                  4         1
# 2966                7        2           7                  6         7
# 2967                8        4           2                  3         1
#
#       SwallowingDifficulty  ClubbingofFingerNails  FrequentCold  DryCough  \
# 0                        3                      1             2         3
# 1                        6                      2             1         7
# 2                        1                      4             6         7
# 3                        4                      5             6         7
# 4                        4                      2             4         2
# ...                    ...                    ...           ...       ...
# 2963                     4                      5             6         7
# 2964                     1                      4             6         7
# 2965                     4                      2             4         2
# 2966                     6                      7             2         3
# 2967                     4                      5             6         7
#
#       Snoring
# 0           4
# 1           2
# 2           2
# 3           5
# 4           3
# ...       ...
# 2963        5
# 2964        2
# 2965        3
# 2966        1
# 2967        5
#
# [2968 rows x 23 columns]

# %%
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2963    1
# 2964    1
# 2965    1
# 2966    1
# 2967    1
# Name: Level, Length: 2968, dtype: int64

# %%
plt.figure(figsize = (10, 5))
sns.countplot(x='Smoking',data=df)
# Out:
# <Axes: xlabel='Smoking', ylabel='count'>

# %%
plt.figure(figsize = (10, 10))
sns.countplot(x='ChestPain',data=df)
# Out:
# <Axes: xlabel='ChestPain', ylabel='count'>

# %%
plt.figure(figsize = (15, 10))
sns.boxplot(x='ChestPain',y='Age',data=df)
# Out:
# <Axes: xlabel='ChestPain', ylabel='Age'>

# %%
plt.figure(figsize = (15, 10))
sns.countplot(x='Smoking',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Smoking', ylabel='count'>

# %%
plt.figure(figsize = (10, 10))
df['Age'].plot.hist()
plt.title('Lungs Cancer Detect in the Age')
# Out:
# Text(0.5, 1.0, 'Lungs Cancer Detect in the Age')

# %%
plt.figure(figsize = (20, 10))
sns.countplot(x='Age',hue='Alcoholuse',data=df)
plt.xlim(0,10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# # Prediction Based On Classification Techniques

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[181,   0],
#        [  0, 413]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
y_proba=model.predict_proba(X_test)

# %% [markdown]
# # KNN

# %%
# Modeling
from sklearn.neighbors import KNeighborsClassifier
k = 3
#Train Model and Predict  
kNN_model = KNeighborsClassifier(n_neighbors=k).fit(X_train,y_train)
kNN_model
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# just for sanity chaeck
ypred = kNN_model.predict(X_test)
ypred[0:5]
# Out:
# array([1, 0, 1, 1, 1], dtype=int64)

# %%
X_test
# Out:
#       Age  Gender  AirPollution  Alcoholuse  DustAllergy  OccuPationalHazards  \
# 2110   65       1             6           8            7                    7
# 2036   55       1             3           1            1                    1
# 2083   25       2             4           5            6                    5
# 870    46       1             6           8            7                    7
# 2501   36       2             2           1            5                    3
# ...   ...     ...           ...         ...          ...                  ...
# 1637   35       2             4           5            6                    5
# 937    38       2             3           2            3                    2
# 1911   33       1             2           4            5                    4
# 287    44       1             2           1            5                    3
# 1016   38       2             2           1            5                    3
#
#       GeneticRisk  chronicLungDisease  BalancedDiet  Obesity  ...  \
# 2110            7                   6             2        4  ...
# 2036            2                   3             4        1  ...
# 2083            5                   4             6        7  ...
# 870             7                   6             7        7  ...
# 2501            2                   3             2        4  ...
# ...           ...                 ...           ...      ...  ...
# 1637            5                   4             6        7  ...
# 937             3                   2             3        2  ...
# 1911            3                   2             2        4  ...
# 287             2                   3             2        4  ...
# 1016            2                   3             2        4  ...
#
#       CoughingofBlood  Fatigue  WeightLoss  ShortnessofBreath  Wheezing  \
# 2110                3        2           7                  6         5
# 2036                3        2           5                  2         1
# 2083                8        8           7                  9         2
# 870                 9        3           2                  4         1
# 2501                4        6           7                  2         5
# ...               ...      ...         ...                ...       ...
# 1637                8        8           7                  9         2
# 937                 1        1           2                  3         2
# 1911                4        3           4                  2         2
# 287                 4        6           7                  2         5
# 1016                4        6           7                  2         5
#
#       SwallowingDifficulty  ClubbingofFingerNails  FrequentCold  DryCough  \
# 2110                     1                      9             3         4
# 2036                     2                      3             4         5
# 2083                     1                      4             6         7
# 870                      4                      2             4         2
# 2501                     8                      1             3         2
# ...                    ...                    ...           ...       ...
# 1637                     1                      4             6         7
# 937                      5                      1             5         1
# 1911                     3                      1             2         3
# 287                      8                      1             3         2
# 1016                     8                      1             3         2
#
#       Snoring
# 2110        2
# 2036        2
# 2083        2
# 870         3
# 2501        3
# ...       ...
# 1637        2
# 937         1
# 1911        4
# 287         3
# 1016        3
#
# [594 rows x 23 columns]

# %%
X_test.shape
# Out:
# (594, 23)

# %%
y_test
# Out:
# 2110    1
# 2036    0
# 2083    1
# 870     1
# 2501    1
#        ..
# 1637    1
# 937     0
# 1911    0
# 287     1
# 1016    1
# Name: Level, Length: 594, dtype: int64

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 594 entries, 2110 to 1016
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    594 non-null    int64
#  1   Gender                 594 non-null    int64
#  2   AirPollution           594 non-null    int64
#  3   Alcoholuse             594 non-null    int64
#  4   DustAllergy            594 non-null    int64
#  5   OccuPationalHazards    594 non-null    int64
#  6   GeneticRisk            594 non-null    int64
#  7   chronicLungDisease     594 non-null    int64
#  8   BalancedDiet           594 non-null    int64
#  9   Obesity                594 non-null    int64
#  10  Smoking                594 non-null    int64
#  11  PassiveSmoker          594 non-null    int64
#  12  ChestPain              594 non-null    int64
#  13  CoughingofBlood        594 non-null    int64
#  14  Fatigue                594 non-null    int64
#  15  WeightLoss             594 non-null    int64
#  16  ShortnessofBreath      594 non-null    int64
#  17  Wheezing               594 non-null    int64
#  18  SwallowingDifficulty   594 non-null    int64
#  19  ClubbingofFingerNails  594 non-null    int64
#  20  FrequentCold           594 non-null    int64
#  21  DryCough               594 non-null    int64
#  22  Snoring                594 non-null    int64
# dtypes: int64(23)
# memory usage: 111.4 KB

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
bestscore=0
list=[]
for k in range(3,12):
    clf_knn=KNeighborsClassifier(n_neighbors=k)
    scores=cross_val_score(clf_knn,X,y,cv=10)
    score=scores.mean()
    list.append(score)
    if score>bestscore:
        bestscore=score
        bestk=k
print("best k is",bestk,"Cross validation score is",bestscore)
# Out:
# best k is 3 Cross validation score is 0.9996632996632997

# %%
from sklearn.neighbors import KNeighborsClassifier
k = 11
model1 = KNeighborsClassifier(n_neighbors=k).fit(X_train,y_train)
model1
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
y_pred = model1.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9983164983164983

# %%
import pickle
pickle.dump(model1, open('model.pkl','wb'))
